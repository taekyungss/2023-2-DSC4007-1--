# %%
import nltk
import konlpy
from nltk import word_tokenize

# %%
sentence='''절망의 반대가 희망은 아니다.
어두운 밤하늘에 별이 빛나듯
희망은 절망 속에 싹트는 거지
만약에 우리가 희망함이 적다면
그 누가 세상을 비추어줄까.
정희성, 희망 공부'''

# %%
from konlpy.tag import Okt
t= Okt()

# %%
print('형태소:', t.morphs(sentence))
print()
print('명사:', t.nouns(sentence))
print()
print('품사 태깅 결과:', t.pos(sentence))
# Out:
# 형태소: ['절망', '의', '반대', '가', '희망', '은', '아니다', '.', '\n', '어', '두운', '밤하늘', '에', '별', '이', '빛나듯', '\n', '희망', '은', '절망', '속', '에', '싹트는', '거지', '\n', '만약', '에', '우리', '가', '희망', '함', '이', '적다면', '\n', '그', '누가', '세상', '을', '비추어줄까', '.', '\n', '정희성', ',', '희망', '공부']
#
# 명사: ['절망', '반대', '희망', '어', '두운', '밤하늘', '별', '희망', '절망', '속', '거지', '만약', '우리', '희망', '함', '그', '누가', '세상', '정희성', '희망', '공부']
#
# 품사 태깅 결과: [('절망', 'Noun'), ('의', 'Josa'), ('반대', 'Noun'), ('가', 'Josa'), ('희망', 'Noun'), ('은', 'Josa'), ('아니다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('어', 'Noun'), ('두운', 'Noun'), ('밤하늘', 'Noun'), ('에', 'Josa'), ('별', 'Noun'), ('이', 'Josa'), ('빛나듯', 'Verb'), ('\n', 'Foreign'), ('희망', 'Noun'), ('은', 'Josa'), ('절망', 'Noun'), ('속', 'Noun'), ('에', 'Josa'), ('싹트는', 'Verb'), ('거지', 'Noun'), ('\n', 'Foreign'), ('만약', 'Noun'), ('에', 'Josa'), ('우리', 'Noun'), ('가', 'Josa'), ('희망', 'Noun'), ('함', 'Noun'), ('이', 'Josa'), ('적다면', 'Verb'), ('\n', 'Foreign'), ('그', 'Noun'), ('누가', 'Noun'), ('세상', 'Noun'), ('을', 'Josa'), ('비추어줄까', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('정희성', 'Noun'), (',', 'Punctuation'), ('희망', 'Noun'), ('공부', 'Noun')]

# %%
from konlpy.corpus import kolaw
const_doc = kolaw.open('constitution.txt').read()

print(type(const_doc))
print(len(const_doc))
print(const_doc[:600])
# Out:
# <class 'str'>
# 18884
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.
#
#        제1장 총강
#   제1조 ① 대한민국은 민주공화국이다.
# ②대한민국의 주권은 국민에게 있고, 모든 권력은 국민으로부터 나온다.
#   제2조 ① 대한민국의 국민이 되는 요건은 법률로 정한다.
# ②국가는 법률이 정하는 바에 의하여 재외국민을 보호할 의무를 진다.
#   제3조 대한민

# %%
t = Okt()
tokens_const = t.morphs(const_doc)

print('#토큰의 수:', len(tokens_const))
print('#앞 100개의 토큰')
print(tokens_const[:100])
# Out:
# #토큰의 수: 8796
# #앞 100개의 토큰
# ['대한민국', '헌법', '\n\n', '유구', '한', '역사', '와', '전통', '에', '빛나는', '우리', '대', '한', '국민', '은', '3', '·', '1', '운동', '으로', '건립', '된', '대한민국', '임시정부', '의', '법', '통과', '불의', '에', '항거', '한', '4', '·', '19', '민주', '이념', '을', '계승', '하고', ',', '조국', '의', '민주', '개혁', '과', '평화', '적', '통일', '의', '사명', '에', '입', '각하', '여', '정의', '·', '인도', '와', '동포', '애', '로써', '민족', '의', '단결', '을', '공고', '히', '하고', ',', '모든', '사회', '적', '폐습', '과', '불의', '를', '타파', '하며', ',', '자율', '과', '조화', '를', '바탕', '으로', '자유민주', '적', '기', '본', '질서', '를', '더욱', '확고히', '하여', '정치', '·', '경제', '·', '사회', '·']

# %%
tokens_const = t.nouns(const_doc)  #형태소 단위로 tokenize 후 명사만 추출
print('#토큰의 수:', len(tokens_const))
print('#앞 100개의 토큰')
print(tokens_const[:100])
# Out:
# #토큰의 수: 3882
# #앞 100개의 토큰
# ['대한민국', '헌법', '유구', '역사', '전통', '우리', '국민', '운동', '건립', '대한민국', '임시정부', '법', '통과', '불의', '항거', '민주', '이념', '계승', '조국', '민주', '개혁', '평화', '통일', '사명', '입', '각하', '정의', '인도', '동포', '애', '로써', '민족', '단결', '공고', '모든', '사회', '폐습', '불의', '타파', '자율', '조화', '바탕', '자유민주', '질서', '더욱', '정치', '경제', '사회', '문화', '모든', '영역', '각인', '기회', '능력', '최고', '도로', '발휘', '자유', '권리', '책임', '의무', '완수', '안', '국민', '생활', '향상', '기하', '밖', '항구', '세계', '평화', '인류', '공영', '이바지', '함', '우리', '우리', '자손', '안전', '자유', '행복', '확보', '것', '다짐', '제정', '차', '개정', '헌법', '이제', '국회', '의결', '국민투표', '개정', '제', '장', '강', '제', '대한민국', '민주공화국', '대한민국']

# %%
tokens_const = [token for token in tokens_const if len(token)  > 1] #한 단어인 명사는 제외 (애, 것, 함, 제, 장)
print('#토큰의 수:', len(tokens_const))
print('#앞 100개의 토큰')
print(tokens_const[:100])
# Out:
# #토큰의 수: 3013
# #앞 100개의 토큰
# ['대한민국', '헌법', '유구', '역사', '전통', '우리', '국민', '운동', '건립', '대한민국', '임시정부', '통과', '불의', '항거', '민주', '이념', '계승', '조국', '민주', '개혁', '평화', '통일', '사명', '각하', '정의', '인도', '동포', '로써', '민족', '단결', '공고', '모든', '사회', '폐습', '불의', '타파', '자율', '조화', '바탕', '자유민주', '질서', '더욱', '정치', '경제', '사회', '문화', '모든', '영역', '각인', '기회', '능력', '최고', '도로', '발휘', '자유', '권리', '책임', '의무', '완수', '국민', '생활', '향상', '기하', '항구', '세계', '평화', '인류', '공영', '이바지', '우리', '우리', '자손', '안전', '자유', '행복', '확보', '다짐', '제정', '개정', '헌법', '이제', '국회', '의결', '국민투표', '개정', '대한민국', '민주공화국', '대한민국', '주권', '국민', '모든', '권력', '국민', '대한민국', '국민', '요건', '법률', '국가', '법률', '재외국민']

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

const_cnt = {}
for word in tokens_const:
    const_cnt[word] = const_cnt.get(word,0) + 1
    
def word_graph(cnt, max_words=10):
    sorted_w = sorted(cnt.items(), key=lambda kv: kv[1])
    print(sorted_w[-max_words:])
    n, w = zip(*sorted_w[-max_words:])
    
    plt.barh(range(len(n)), w,tick_label=n)
    plt.show()
    
word_graph(const_cnt, max_words=20)
# Out:
# [('조직', 18), ('국회의원', 18), ('임기', 18), ('직무', 19), ('국무총리', 19), ('자유', 20), ('정부', 20), ('선거', 20), ('임명', 20), ('권리', 21), ('의원', 21), ('사항', 23), ('기타', 26), ('모든', 37), ('헌법', 53), ('국민', 61), ('국회', 68), ('국가', 73), ('대통령', 83), ('법률', 127)]

# %%
from wordcloud import WordCloud
font_path = 'c:/Windows/Fonts/malgun.ttf'
word_cloud = WordCloud(font_path = font_path).generate(const_doc)  #generate를 통해 형태소 분석 결과 대신 원문을 넣는다

plt.axis("off")
plt.imshow(word_cloud, interpolation='bilinear')
plt.show()


이미지 너비 높이 지정 > width, heigtht
배경색 > background_color

# %%
wordcloud = WordCloud(
    font_path = font_path,
    max_font_size = 100,
    width=800,
    height=400,
    background_color='white',
    max_words=50
)

wordcloud.generate_from_frequencies(const_cnt)   #원문이 아니라 형태소 분석 결과로부터 워드 클라우드 생성

plt.axis("off")
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
for token in tokens_const:
    list_1 = ['대한민국','법률','국가']
    list_2 = ['대통령','국회','임기','국무총리','정부','국무위원','선거']
    list_3 = ['공무원','경제','노력','직무','관리']
    if token in list_1:
        print('대한민국 법률')
    elif token in list_2:
        print('대통령')
    elif token in list_3:
        print('공무원')
    else:
        pass
# Out:
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 공무원
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 공무원
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 공무원
# 대통령
# 대통령
# 대통령
# 대통령
# 공무원
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 공무원
# 대한민국 법률
# 대통령
# 공무원
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 공무원
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 공무원
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 공무원
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대통령
# 공무원
# 대한민국 법률
# 공무원
# 대통령
# 공무원
# 공무원
# 공무원
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 공무원
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대통령
# 공무원
# 대통령
# 공무원
# 대통령
# 공무원
# 대통령
# 공무원
# 대통령
# 대통령
# 대통령
# 대통령
# 공무원
# 대통령
# 공무원
# 공무원
# 대한민국 법률
# 대통령
# 공무원
# 공무원
# 대한민국 법률
# 대통령
# 공무원
# 대통령
# 대통령
# 공무원
# 공무원
# 대한민국 법률
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대통령
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 공무원
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 대한민국 법률
# 공무원
# 공무원
# 대한민국 법률
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대한민국 법률
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 대통령
# 공무원
# 대통령
# 공무원
# 공무원
# 공무원
# 대통령
# 공무원
# 대통령
# 공무원
# 공무원
# 공무원

# %%
categories = ["카테고리1", "카테고리2"]
risk_scores = {"카테고리1": 0.3, "카테고리2": 0.5}
category_weights = {
    1: 1.0,  # 1개 카테고리에 속한 경우의 가중치
    2: 1.2,  # 2개 카테고리에 속한 경우의 가중치
    3: 1.5   # 3개 카테고리에 속한 경우의 가중치
}

# 항목이 속한 카테고리 목록
item_categories = ["카테고리1", "카테고리2", "카테고리3"]

# 속한 카테고리의 개수 계산
category_count = len(item_categories)

# 가중치 할당
if category_count in category_weights:
    weight = category_weights[category_count]
else:
    # 원하는 방식으로 처리 (예: 특별한 경우에 대한 가중치 설정)
    weight = 1.0

# 위험도 계산
risk_score = 0.3  # 카테고리의 위험도 (예시)
total_risk = risk_score * weight

print("총 위험도:", total_risk)
# Out:
# 총 위험도: 0.44999999999999996

# %%
# 단어별 빈도수 계산
word_counts = Counter(tokens)

# 가장 빈도가 높은 단어를 찾음
most_common_word, most_common_count = word_counts.most_common(1)[0]

# 결과 출력
print(f"가장 빈도가 높은 단어: {most_common_word}, 빈도수: {most_common_count}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\UserK\Desktop\data\데캡디\NLTK.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/data/%EB%8D%B0%EC%BA%A1%EB%94%94/NLTK.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # 단어별 빈도수 계산
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/data/%EB%8D%B0%EC%BA%A1%EB%94%94/NLTK.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> word_counts = Counter(tokens)
#       <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/data/%EB%8D%B0%EC%BA%A1%EB%94%94/NLTK.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> # 가장 빈도가 높은 단어를 찾음
#       <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/data/%EB%8D%B0%EC%BA%A1%EB%94%94/NLTK.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> most_common_word, most_common_count = word_counts.most_common(1)[0]
#
# NameError: name 'Counter' is not defined
